# %%
import nltk
from nltk.stem import isri
from nltk.corpus import stopwords

import gensim
import numpy as np
import pandas as pd
import pyLDAvis
import spacy

# %% [markdown]
# ### Data Loading

# %%
data = pd.read_csv('Data/posts.csv', encoding='utf-8',error_bad_lines=False);
docs=data['body'].drop_duplicates().values.tolist()
data_text = data[['body']]
data_text['id'] = data_text.index
documents = data_text
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Data Preprocessing

# %%
STOPWORDS = set(stopwords.words('english')+stopwords.words('arabic'))

tobespace_re = r'[\/\\(){}\[\]\|\"\'،…—.;,-=+$%^&*:÷×؛~٪؟?!_#@]'
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)

def normalize(text):
    text = re.sub("[إأآ]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("[ؤئ]", "ء", text)
    text = re.sub("هة", "ه", text)
    text = re.sub("[ة]", "ه", text)
    text = re.sub("گ", "ك", text)
    text = re.sub(arabic_diacritics, '', text)
    return text

def clean(text):
    text = re.sub(r'http\S+', '', text)    #لإزالة الروابط
    text = re.sub(r'\S+@\S+\s?', '', text)  #لإزالة البريد الإلكتروني  
    text = re.sub(r'@\S+', '', text)       #لإزالة المنشنات
    text = re.sub(r'pic.\S+', '', text)    #لإزالة الصور
#     stemmer = isri.ISRIStemmer()
#     text = " ".join(stemmer.stem(w) for w in text.split() if ( (w not in STOPWORDS) and (len(w)>3) ))
    text = " ".join(w for w in text.split() if w not in STOPWORDS)
    text = normalize(text)
    text = re.sub(r'(.)\1+', r'\1\1', text)         # إزالة الأحرف المكررة أكثر من مرتين
    text = re.sub(r'(.)(.)(\1\2)+', r'\1\2', text)  #إزالة ثنائية الأحرف المكررة
    text = re.sub(tobespace_re, ' ', text)          # الإستبدال بفراغ
    text = re.sub(r'\s+', ' ', text)                #إزالة الفراغات المكررة 
    text = text.lower()
    clean = [w for w in text.split()]
    return clean

# %%
processed_docs = documents['body'].map(clean)
processed_docs[:10]
# Out:
# 0    [ابن, يالسبيعيابنتي, بدا, كشف, غرز, جنس, خااءف...
# 1    [لمذ, لماذ, لمذ, احس, الظ, اخر, قلب, اسا, الظ,...
# 2    [خمس, عشر, عنا, نقذ, فوت, اون, بسم, الل, رحم, ...
# 3    [ف, انصات, كيف, علم, انص, رات, ناس, تحس, عمل, ...
# 4    [بكء, دكتور, سبيعيالسلام, علي, رحم, الل, وبر, ...
# 5    [طءر, سجد, هطر, سجد, منقول, عجب, كرم, قصه, نقل...
# 6    [علم, خفف, غرب, نوع, مامعلوم, خفف, غرب, نوع, ع...
# 7    [فته, خرج, انف, مسك, تغسيلهافتاه, خرج, انف, مس...
# 8    [موسيقي, اسمع, وتمتعليش, سمع, نست, انه, حرم, ي...
# 9    [علاج, حسد, لايفوت, م, جدا, بسم, الل, رحم, رحم...
# Name: body, dtype: object

# %% [markdown]
# #### Bag of Words on the Data set

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 ابن
# 1 اثر
# 2 اخه
# 3 انه
# 4 بان
# 5 بدا
# 6 بدت
# 7 ترك
# 8 تعد
# 9 جنس
# 10 خااءفه

# %% [markdown]
# Filter out tokens that appear in
#
# >less than 15 documents (absolute number) or
# >more than 0.5 documents (fraction of total corpus size, not absolute number).
# >after the above two steps, keep only the first 100000 most frequent tokens.

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %% [markdown]
# Gensim doc2bow
# For each document we create a dictionary reporting how many
# words and how many times those words appear. Save this to ‘bow_corpus’, then check our selected document earlier.

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[4310]
# Out:
# [(1, 1),
#  (2, 4),
#  (3, 2),
#  (5, 1),
#  (16, 9),
#  (21, 1),
#  (23, 1),
#  (26, 1),
#  (29, 4),
#  (30, 1),
#  (32, 1),
#  (37, 24),
#  (46, 2),
#  (54, 1),
#  (55, 1),
#  (71, 4),
#  (85, 1),
#  (96, 1),
#  (121, 1),
#  (123, 1),
#  (142, 5),
#  (143, 2),
#  (147, 1),
#  (158, 2),
#  (164, 2),
#  (168, 1),
#  (174, 1),
#  (179, 2),
#  (180, 4),
#  (185, 1),
#  (190, 2),
#  (198, 5),
#  (211, 4),
#  (218, 3),
#  (222, 1),
#  (225, 1),
#  (226, 3),
#  (230, 1),
#  (237, 1),
#  (244, 1),
#  (248, 1),
#  (249, 1),
#  (250, 10),
#  (256, 1),
#  (258, 1),
#  (260, 1),
#  (264, 1),
#  (276, 2),
#  (279, 1),
#  (282, 4),
#  (291, 1),
#  (294, 5),
#  (335, 1),
#  (337, 1),
#  (349, 1),
#  (352, 2),
#  (353, 1),
#  (361, 1),
#  (376, 1),
#  (378, 1),
#  (381, 2),
#  (402, 18),
#  (411, 1),
#  (418, 2),
#  (421, 2),
#  (429, 1),
#  (437, 4),
#  (440, 1),
#  (442, 3),
#  (451, 1),
#  (453, 2),
#  (455, 1),
#  (457, 2),
#  (463, 15),
#  (468, 1),
#  (479, 1),
#  (483, 1),
#  (506, 1),
#  (528, 1),
#  (530, 2),
#  (534, 1),
#  (553, 1),
#  (558, 1),
#  (559, 1),
#  (562, 3),
#  (564, 1),
#  (596, 3),
#  (600, 1),
#  (602, 1),
#  (630, 2),
#  (640, 1),
#  (664, 2),
#  (665, 1),
#  (682, 3),
#  (700, 1),
#  (702, 1),
#  (703, 4),
#  (727, 1),
#  (729, 1),
#  (737, 1),
#  (744, 1),
#  (747, 1),
#  (751, 1),
#  (771, 1),
#  (778, 1),
#  (780, 1),
#  (781, 2),
#  (791, 1),
#  (812, 1),
#  (817, 1),
#  (819, 4),
#  (822, 5),
#  (824, 1),
#  (830, 2),
#  (851, 1),
#  (856, 1),
#  (882, 6),
#  (898, 2),
#  (899, 1),
#  (902, 2),
#  (908, 1),
#  (920, 1),
#  (923, 1),
#  (935, 1),
#  (939, 1),
#  (943, 1),
#  (951, 2),
#  (954, 1),
#  (1014, 3),
#  (1023, 1),
#  (1032, 1),
#  (1119, 3),
#  (1122, 1),
#  (1126, 1),
#  (1159, 1),
#  (1162, 1),
#  (1167, 1),
#  (1211, 1),
#  (1214, 1),
#  (1283, 2),
#  (1296, 1),
#  (1300, 1),
#  (1344, 1),
#  (1346, 2),
#  (1361, 1),
#  (1368, 2),
#  (1384, 3),
#  (1389, 1),
#  (1435, 1),
#  (1495, 1),
#  (1497, 1),
#  (1498, 1),
#  (1500, 1),
#  (1502, 2),
#  (1529, 1),
#  (1555, 1),
#  (1574, 1),
#  (1585, 1),
#  (1588, 10),
#  (1604, 1),
#  (1612, 2),
#  (1622, 1),
#  (1625, 1),
#  (1657, 2),
#  (1658, 1),
#  (1686, 2),
#  (1746, 2),
#  (1786, 1),
#  (1790, 3),
#  (1794, 1),
#  (1824, 2),
#  (1825, 3),
#  (1857, 1),
#  (1870, 1),
#  (1939, 1),
#  (1945, 1),
#  (2065, 1),
#  (2089, 3),
#  (2092, 1),
#  (2104, 1),
#  (2165, 1),
#  (2182, 1),
#  (2204, 1),
#  (2254, 1),
#  (2306, 3),
#  (2331, 1),
#  (2339, 3),
#  (2415, 1),
#  (2430, 1),
#  (2458, 2),
#  (2478, 1),
#  (2480, 1),
#  (2481, 1),
#  (2521, 1),
#  (2522, 1),
#  (2547, 1),
#  (2558, 5),
#  (2568, 1),
#  (2585, 2),
#  (2652, 1),
#  (2686, 1),
#  (2780, 1),
#  (2798, 1),
#  (2874, 1),
#  (2880, 1),
#  (2912, 1),
#  (2998, 1),
#  (3052, 1),
#  (3102, 1),
#  (3151, 1),
#  (3272, 1),
#  (3282, 1),
#  (3334, 1),
#  (3371, 1),
#  (3477, 1),
#  (3494, 1),
#  (3547, 2),
#  (3638, 1),
#  (3689, 1),
#  (3750, 1),
#  (3759, 1),
#  (3775, 2),
#  (3842, 1),
#  (3929, 4),
#  (4026, 6),
#  (4107, 1),
#  (4176, 1),
#  (4341, 1),
#  (4390, 1),
#  (4419, 1),
#  (4425, 1),
#  (4503, 1),
#  (4521, 1),
#  (4661, 2),
#  (4694, 3),
#  (4709, 1),
#  (4837, 1),
#  (4891, 1),
#  (5048, 1),
#  (5076, 2),
#  (5145, 1),
#  (5148, 1),
#  (5198, 2),
#  (5285, 2),
#  (5502, 1),
#  (5579, 1),
#  (5627, 1),
#  (5743, 1),
#  (5853, 1),
#  (6002, 1),
#  (6422, 1),
#  (6759, 1),
#  (6904, 1),
#  (7137, 2),
#  (7227, 2),
#  (7236, 1),
#  (7255, 1),
#  (7265, 3),
#  (7379, 2)]

# %% [markdown]
# Preview Bag Of Words for our sample preprocessed document.

# %%
bow_doc_4310 = bow_corpus[4310]
for i in range(len(bow_doc_4310)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_4310[i][0], 
                                               dictionary[bow_doc_4310[i][0]], 
bow_doc_4310[i][1]))
# Out:
# Word 1 ("اثر") appears 1 time.
# Word 2 ("اخه") appears 4 time.
# Word 3 ("انه") appears 2 time.
# Word 5 ("بدا") appears 1 time.
# Word 16 ("عمل") appears 9 time.
# Word 21 ("كشف") appears 1 time.
# Word 23 ("لدي") appears 1 time.
# Word 26 ("مثل") appears 1 time.
# Word 29 ("وحد") appears 4 time.
# Word 30 ("ولك") appears 1 time.
# Word 32 ("احس") appears 1 time.
# Word 37 ("امر") appears 24 time.
# Word 46 ("حول") appears 2 time.
# Word 54 ("رجل") appears 1 time.
# Word 55 ("رحم") appears 1 time.
# Word 71 ("كانت") appears 4 time.
# Word 85 ("وجد") appears 1 time.
# Word 96 ("ارض") appears 1 time.
# Word 121 ("بغر") appears 1 time.
# Word 123 ("بلغ") appears 1 time.
# Word 142 ("جمع") appears 5 time.
# Word 143 ("جنب") appears 2 time.
# Word 147 ("حرب") appears 1 time.
# Word 158 ("خرج") appears 2 time.
# Word 164 ("خلل") appears 2 time.
# Word 168 ("دخل") appears 1 time.
# Word 174 ("ذكر") appears 1 time.
# Word 179 ("رسل") appears 2 time.
# Word 180 ("رفع") appears 4 time.
# Word 185 ("سبق") appears 1 time.
# Word 190 ("سلم") appears 2 time.
# Word 198 ("شعب") appears 5 time.
# Word 211 ("طلب") appears 4 time.
# Word 218 ("عدد") appears 3 time.
# Word 222 ("عشر") appears 1 time.
# Word 225 ("علق") appears 1 time.
# Word 226 ("علم") appears 3 time.
# Word 230 ("عني") appears 1 time.
# Word 237 ("فان") appears 1 time.
# Word 244 ("فشل") appears 1 time.
# Word 248 ("قبل") appears 1 time.
# Word 249 ("قدم") appears 1 time.
# Word 250 ("قرب") appears 10 time.
# Word 256 ("كان") appears 1 time.
# Word 258 ("كبر") appears 1 time.
# Word 260 ("كثف") appears 1 time.
# Word 264 ("كمل") appears 1 time.
# Word 276 ("نتج") appears 2 time.
# Word 279 ("نزل") appears 1 time.
# Word 282 ("نهم") appears 4 time.
# Word 291 ("وذل") appears 1 time.
# Word 294 ("وصل") appears 5 time.
# Word 335 ("حدث") appears 1 time.
# Word 337 ("خبر") appears 1 time.
# Word 349 ("شكل") appears 1 time.
# Word 352 ("صمت") appears 2 time.
# Word 353 ("ضرب") appears 1 time.
# Word 361 ("فعل") appears 1 time.
# Word 376 ("نري") appears 1 time.
# Word 378 ("نفر") appears 1 time.
# Word 381 ("هدء") appears 2 time.
# Word 402 ("جهد") appears 18 time.
# Word 411 ("شدد") appears 1 time.
# Word 418 ("علي") appears 2 time.
# Word 421 ("قوت") appears 2 time.
# Word 429 ("بتج") appears 1 time.
# Word 437 ("حال") appears 4 time.
# Word 440 ("خري") appears 1 time.
# Word 442 ("دفع") appears 3 time.
# Word 451 ("سبح") appears 1 time.
# Word 453 ("سرع") appears 2 time.
# Word 455 ("سمر") appears 1 time.
# Word 457 ("شهد") appears 2 time.
# Word 463 ("طءر") appears 15 time.
# Word 468 ("عدل") appears 1 time.
# Word 479 ("قصه") appears 1 time.
# Word 483 ("لال") appears 1 time.
# Word 506 ("ثني") appears 1 time.
# Word 528 ("صبح") appears 1 time.
# Word 530 ("طلق") appears 2 time.
# Word 534 ("عمد") appears 1 time.
# Word 553 ("يضء") appears 1 time.
# Word 558 ("اخري") appears 1 time.
# Word 559 ("اسد") appears 1 time.
# Word 562 ("الي") appears 3 time.
# Word 564 ("اهل") appears 1 time.
# Word 596 ("ستر") appears 3 time.
# Word 600 ("عرض") appears 1 time.
# Word 602 ("عليها") appears 1 time.
# Word 630 ("وكانت") appears 2 time.
# Word 640 ("حدد") appears 1 time.
# Word 664 ("ايم") appears 2 time.
# Word 665 ("جدا") appears 1 time.
# Word 682 ("اسر") appears 3 time.
# Word 700 ("نسب") appears 1 time.
# Word 702 ("وفق") appears 1 time.
# Word 703 ("وقع") appears 4 time.
# Word 727 ("وقف") appears 1 time.
# Word 729 ("يدن") appears 1 time.
# Word 737 ("اعد") appears 1 time.
# Word 744 ("بدر") appears 1 time.
# Word 747 ("بسط") appears 1 time.
# Word 751 ("بكر") appears 1 time.
# Word 771 ("رور") appears 1 time.
# Word 778 ("ساع") appears 1 time.
# Word 780 ("سعه") appears 1 time.
# Word 781 ("سفر") appears 2 time.
# Word 791 ("عدم") appears 1 time.
# Word 812 ("ليل") appears 1 time.
# Word 817 ("نبه") appears 1 time.
# Word 819 ("نطق") appears 4 time.
# Word 822 ("والتي") appears 5 time.
# Word 824 ("وعد") appears 1 time.
# Word 830 ("ولي") appears 2 time.
# Word 851 ("صور") appears 1 time.
# Word 856 ("عجل") appears 1 time.
# Word 882 ("ءمن") appears 6 time.
# Word 898 ("زبر") appears 2 time.
# Word 899 ("سمء") appears 1 time.
# Word 902 ("عسكر") appears 2 time.
# Word 908 ("فرح") appears 1 time.
# Word 920 ("اخا") appears 1 time.
# Word 923 ("اكد") appears 1 time.
# Word 935 ("خصه") appears 1 time.
# Word 939 ("درج") appears 1 time.
# Word 943 ("سوق") appears 1 time.
# Word 951 ("طار") appears 2 time.
# Word 954 ("طلع") appears 1 time.
# Word 1014 ("بطل") appears 3 time.
# Word 1023 ("تفق") appears 1 time.
# Word 1032 ("جمل") appears 1 time.
# Word 1119 ("قتل") appears 3 time.
# Word 1122 ("قط") appears 1 time.
# Word 1126 ("قيم") appears 1 time.
# Word 1159 ("ملا") appears 1 time.
# Word 1162 ("نار") appears 1 time.
# Word 1167 ("نشر") appears 1 time.
# Word 1211 ("بلد") appears 1 time.
# Word 1214 ("حشد") appears 1 time.
# Word 1283 ("سجل") appears 2 time.
# Word 1296 ("قءد") appears 1 time.
# Word 1300 ("لرد") appears 1 time.
# Word 1344 ("منع") appears 1 time.
# Word 1346 ("نصف") appears 2 time.
# Word 1361 ("تبع") appears 1 time.
# Word 1368 ("حمل") appears 2 time.
# Word 1384 ("عدو") appears 3 time.
# Word 1389 ("قوه") appears 1 time.
# Word 1435 ("عصب") appears 1 time.
# Word 1495 ("ضيع") appears 1 time.
# Word 1497 ("غرر") appears 1 time.
# Word 1498 ("غمر") appears 1 time.
# Word 1500 ("فقد") appears 1 time.
# Word 1502 ("قلع") appears 2 time.
# Word 1529 ("ونس") appears 1 time.
# Word 1555 ("فرغ") appears 1 time.
# Word 1574 ("باستخدام") appears 1 time.
# Word 1585 ("شهداء") appears 1 time.
# Word 1588 ("عرب") appears 10 time.
# Word 1604 ("تحد") appears 1 time.
# Word 1612 ("سقط") appears 2 time.
# Word 1622 ("مرت") appears 1 time.
# Word 1625 ("واع") appears 1 time.
# Word 1657 ("شمل") appears 2 time.
# Word 1658 ("صرخ") appears 1 time.
# Word 1686 ("هلك") appears 2 time.
# Word 1746 ("يلم") appears 2 time.
# Word 1786 ("جوز") appears 1 time.
# Word 1790 ("حطم") appears 3 time.
# Word 1794 ("دار") appears 1 time.
# Word 1824 ("فجا") appears 2 time.
# Word 1825 ("فرد") appears 3 time.
# Word 1857 ("ولم") appears 1 time.
# Word 1870 ("بهذا") appears 1 time.
# Word 1939 ("نره") appears 1 time.
# Word 1945 ("ونح") appears 1 time.
# Word 2065 ("دعم") appears 1 time.
# Word 2089 ("تحر") appears 3 time.
# Word 2092 ("تغط") appears 1 time.
# Word 2104 ("سلف") appears 1 time.
# Word 2165 ("ايد") appears 1 time.
# Word 2182 ("اصب") appears 1 time.
# Word 2204 ("جوه") appears 1 time.
# Word 2254 ("كاذيب") appears 1 time.
# Word 2306 ("قيد") appears 3 time.
# Word 2331 ("شرس") appears 1 time.
# Word 2339 ("هجم") appears 3 time.
# Word 2415 ("حار") appears 1 time.
# Word 2430 ("قلم") appears 1 time.
# Word 2458 ("جهز") appears 2 time.
# Word 2478 ("وبق") appears 1 time.
# Word 2480 ("يمل") appears 1 time.
# Word 2481 ("ارسال") appears 1 time.
# Word 2521 ("زود") appears 1 time.
# Word 2522 ("ستي") appears 1 time.
# Word 2547 ("وشر") appears 1 time.
# Word 2558 ("حرس") appears 5 time.
# Word 2568 ("سحه") appears 1 time.
# Word 2585 ("فور") appears 2 time.
# Word 2652 ("ناثر") appears 1 time.
# Word 2686 ("سرق") appears 1 time.
# Word 2780 ("رعه") appears 1 time.
# Word 2798 ("عزل") appears 1 time.
# Word 2874 ("بلش") appears 1 time.
# Word 2880 ("مكن") appears 1 time.
# Word 2912 ("وزر") appears 1 time.
# Word 2998 ("اطلاق") appears 1 time.
# Word 3052 ("ورج") appears 1 time.
# Word 3102 ("اشر") appears 1 time.
# Word 3151 ("سد") appears 1 time.
# Word 3272 ("كثيرا") appears 1 time.
# Word 3282 ("خلو") appears 1 time.
# Word 3334 ("سلح") appears 1 time.
# Word 3371 ("ميد") appears 1 time.
# Word 3477 ("نجر") appears 1 time.
# Word 3494 ("جند") appears 1 time.
# Word 3547 ("شبك") appears 2 time.
# Word 3638 ("سعف") appears 1 time.
# Word 3689 ("بغت") appears 1 time.
# Word 3750 ("شءم") appears 1 time.
# Word 3759 ("كار") appears 1 time.
# Word 3775 ("تمك") appears 2 time.
# Word 3842 ("طقت") appears 1 time.
# Word 3929 ("كبل") appears 4 time.
# Word 4026 ("غنس") appears 6 time.
# Word 4107 ("مم") appears 1 time.
# Word 4176 ("وقو") appears 1 time.
# Word 4341 ("اصو") appears 1 time.
# Word 4390 ("درت") appears 1 time.
# Word 4419 ("لقو") appears 1 time.
# Word 4425 ("هول") appears 1 time.
# Word 4503 ("قحم") appears 1 time.
# Word 4521 ("حءل") appears 1 time.
# Word 4661 ("c") appears 2 time.
# Word 4694 ("عرك") appears 3 time.
# Word 4709 ("تيق") appears 1 time.
# Word 4837 ("بكف") appears 1 time.
# Word 4891 ("شهي") appears 1 time.
# Word 5048 ("تاح") appears 1 time.
# Word 5076 ("بور") appears 2 time.
# Word 5145 ("جثث") appears 1 time.
# Word 5148 ("رشش") appears 1 time.
# Word 5198 ("طرز") appears 2 time.
# Word 5285 ("تور") appears 2 time.
# Word 5502 ("زرقاء") appears 1 time.
# Word 5579 ("وبغ") appears 1 time.
# Word 5627 ("تسق") appears 1 time.
# Word 5743 ("جيت") appears 1 time.
# Word 5853 ("وطر") appears 1 time.
# Word 6002 ("هال") appears 1 time.
# Word 6422 ("حمز") appears 1 time.
# Word 6759 ("ارو") appears 1 time.
# Word 6904 ("فزز") appears 1 time.
# Word 7137 ("شلك") appears 2 time.
# Word 7227 ("طقم") appears 2 time.
# Word 7236 ("وغط") appears 1 time.
# Word 7255 ("يستخدمون") appears 1 time.
# Word 7265 ("نحز") appears 3 time.
# Word 7379 ("منطقه") appears 2 time.

# %% [markdown]
# TF-IDF
#
# Create tf-idf model object using models.TfidfModel on ‘bow_corpus’ and save it to ‘tfidf’, then apply transformation to the entire corpus and call it ‘corpus_tfidf’. Finally we preview TF-IDF scores for our first document.

# %%
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.11926844028978215),
#  (1, 0.09951728522556409),
#  (2, 0.1279280216482939),
#  (3, 0.07853007524450244),
#  (4, 0.20330284308410904),
#  (5, 0.0935026632782139),
#  (6, 0.1794926550969176),
#  (7, 0.13671062809845977),
#  (8, 0.12466424474741321),
#  (9, 0.1391418226264802),
#  (10, 0.12139416359477628),
#  (11, 0.10967040093886413),
#  (12, 0.11268044184862377),
#  (13, 0.08291217117391671),
#  (14, 0.11719880674787139),
#  (15, 0.07525290064735914),
#  (16, 0.05271547087421837),
#  (17, 0.18407775509636765),
#  (18, 0.6575550913008688),
#  (19, 0.09676246994489064),
#  (20, 0.12218912497976632),
#  (21, 0.22543690855202006),
#  (22, 0.11882914388214565),
#  (23, 0.13287568274541597),
#  (24, 0.17761765617407252),
#  (25, 0.15583860788437154),
#  (26, 0.09876375046061575),
#  (27, 0.18181706588166663),
#  (28, 0.22276949897694923),
#  (29, 0.06188522727343813),
#  (30, 0.09530642448233898),
#  (31, 0.12084156013786333)]

# %% [markdown]
# Running LDA using Bag of Words
#
# Train our lda model using gensim.models.LdaMulticore and save it to ‘lda_model’

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %% [markdown]
# For each topic, we will explore the words occuring in that topic and its relative weight.

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.019*"سلم" + 0.018*"زوج" + 0.014*"رسل" + 0.007*"كلم" + 0.006*"رحم" + 0.006*"حمد" + 0.005*"علم" + 0.005*"علي" + 0.005*"فقل" + 0.005*"حدث"
# Topic: 1
# Words: 0.017*"علم" + 0.010*"شكل" + 0.007*"كثر" + 0.007*"فكر" + 0.007*"وضع" + 0.006*"كلم" + 0.006*"عرف" + 0.005*"جمع" + 0.005*"دكتور" + 0.005*"كتب"
# Topic: 2
# Words: 0.014*"سلم" + 0.011*"علم" + 0.010*"قلب" + 0.006*"ذكر" + 0.006*"عمل" + 0.006*"جمع" + 0.006*"امر" + 0.005*"عبد" + 0.005*"انس" + 0.004*"رحم"
# Topic: 3
# Words: 0.008*"علم" + 0.008*"زوج" + 0.007*"عرف" + 0.007*"سلم" + 0.007*"كلم" + 0.006*"عمل" + 0.006*"امر" + 0.006*"جمع" + 0.006*"دخل" + 0.005*"ولد"
# Topic: 4
# Words: 0.010*"شعر" + 0.008*"عمل" + 0.007*"فكر" + 0.006*"كثر" + 0.006*"علم" + 0.006*"حدث" + 0.006*"فعل" + 0.005*"كلم" + 0.005*"شخص" + 0.005*"عرف"
# Topic: 5
# Words: 0.012*"سلم" + 0.012*"رحم" + 0.011*"جمع" + 0.009*"راه" + 0.008*"كتب" + 0.007*"علم" + 0.007*"رجل" + 0.007*"درس" + 0.006*"سعد" + 0.006*"علي"
# Topic: 6
# Words: 0.010*"شعر" + 0.008*"نظر" + 0.007*"قلب" + 0.005*"حول" + 0.005*"علم" + 0.005*"عرف" + 0.005*"كثر" + 0.004*"سءل" + 0.004*"دمع" + 0.004*"دخل"
# Topic: 7
# Words: 0.013*"شكل" + 0.013*"علج" + 0.011*"رحم" + 0.009*"عمل" + 0.009*"جمع" + 0.009*"علي" + 0.008*"كثر" + 0.006*"علم" + 0.006*"شخص" + 0.006*"سبب"
# Topic: 8
# Words: 0.013*"شكل" + 0.012*"طفل" + 0.012*"علم" + 0.009*"جمع" + 0.008*"عرف" + 0.008*"سلم" + 0.008*"رحم" + 0.007*"قدر" + 0.006*"عمل" + 0.006*"علي"
# Topic: 9
# Words: 0.021*"رحم" + 0.014*"علي" + 0.011*"سلم" + 0.007*"علم" + 0.007*"صدق" + 0.007*"وبر" + 0.007*"كثر" + 0.005*"وحد" + 0.005*"شكر" + 0.005*"عرف"

# %% [markdown]
# ### Running LDA using TF-IDF

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.003*"رحم" + 0.003*"سلم" + 0.002*"قلب" + 0.002*"رسل" + 0.002*"علم" + 0.002*"جمع" + 0.002*"عرف" + 0.002*"صور" + 0.002*"حضر" + 0.002*"علي"
# Topic: 1 Word: 0.004*"رحم" + 0.004*"ندي" + 0.003*"وبر" + 0.003*"دكتور" + 0.003*"سلم" + 0.003*"علي" + 0.003*"مني" + 0.003*"شكر" + 0.003*"عضء" + 0.003*"رجو"
# Topic: 2 Word: 0.003*"رحم" + 0.003*"سلم" + 0.003*"زوج" + 0.002*"لحب" + 0.002*"دكتور" + 0.002*"رسل" + 0.002*"عرف" + 0.002*"جمل" + 0.002*"شكر" + 0.002*"وبر"
# Topic: 3 Word: 0.003*"زوج" + 0.003*"شكل" + 0.003*"علم" + 0.002*"سلم" + 0.002*"عمل" + 0.002*"كلم" + 0.002*"شعر" + 0.002*"رحم" + 0.002*"كثر" + 0.002*"عرف"
# Topic: 4 Word: 0.005*"رحم" + 0.004*"ندي" + 0.004*"شكل" + 0.004*"زوج" + 0.004*"وبر" + 0.004*"شكر" + 0.003*"علي" + 0.003*"رجو" + 0.003*"دكتور" + 0.003*"سلم"
# Topic: 5 Word: 0.003*"سلم" + 0.003*"رحم" + 0.003*"رسل" + 0.002*"زوج" + 0.002*"شكر" + 0.002*"علم" + 0.002*"شكل" + 0.002*"علي" + 0.002*"عرف" + 0.002*"جمع"
# Topic: 6 Word: 0.003*"سلم" + 0.003*"رحم" + 0.002*"رسل" + 0.002*"عضه" + 0.002*"سبح" + 0.002*"جمع" + 0.002*"علم" + 0.002*"علج" + 0.002*"علي" + 0.002*"كلم"
# Topic: 7 Word: 0.004*"رحم" + 0.004*"علج" + 0.003*"دكتور" + 0.003*"ندي" + 0.003*"شكر" + 0.003*"سلم" + 0.003*"سءل" + 0.003*"جمع" + 0.003*"وبر" + 0.003*"علي"
# Topic: 8 Word: 0.003*"رحم" + 0.003*"شكل" + 0.002*"وبر" + 0.002*"علي" + 0.002*"علج" + 0.002*"زوج" + 0.002*"سلم" + 0.002*"شكر" + 0.002*"علم" + 0.002*"سءل"
# Topic: 9 Word: 0.004*"زوج" + 0.003*"علج" + 0.003*"رحم" + 0.003*"شكل" + 0.002*"سلم" + 0.002*"جمع" + 0.002*"دكتور" + 0.002*"شكر" + 0.002*"عمل" + 0.002*"شعر"

# %% [markdown]
# ### Performance evaluation by classifying sample document using LDA Bag of Words model
#
# We will check where our test document would be classified.

# %%
processed_docs[4310]
# Out:
# ['عمل',
#  'كماندوز',
#  'امر',
#  'حال',
#  'عمل',
#  'كماندوز',
#  'امر',
#  'غنس',
#  'عمل',
#  'كماندوز',
#  'امر',
#  'ءمن',
#  'قندهار',
#  'عمل',
#  'كماندوز',
#  'طار',
#  'سفر',
#  'جنب',
#  'هلمند',
#  'عمل',
#  'كماندوز',
#  'عسكر',
#  'اخه',
#  'بلش',
#  'قلم',
#  'عدل',
#  'عمل',
#  'وقع',
#  'يدن',
#  'درت',
#  'ميد',
#  'نتج',
#  'سجل',
#  'لدي',
#  'سجل',
#  'امر',
#  'ونح',
#  'تحد',
#  'قيد',
#  'عسكر',
#  'امر',
#  'وزر',
#  'دفع',
#  'رامسفيلد',
#  'ذكر',
#  'شعب',
#  'امر',
#  'علي',
#  'كار',
#  'قبل',
#  'بدا',
#  'بطل',
#  'جهد',
#  'امر',
#  'شكل',
#  'سرع',
#  'عدد',
#  'جهد',
#  'عرب',
#  'غنس',
#  'خلل',
#  'حرب',
#  'علم',
#  'شعب',
#  'سلم',
#  'خصه',
#  'شعب',
#  'علم',
#  'شعب',
#  'امر',
#  'هول',
#  'كاذيب',
#  'سوق',
#  'نتج',
#  'ورج',
#  'علم',
#  'امر',
#  'سد',
#  'جهد',
#  'قلع',
#  'جنك',
#  'شمل',
#  'غنس',
#  'جهد',
#  'عرب',
#  'شهد',
#  'كمل',
#  'جهد',
#  'شمل',
#  'كبل',
#  'قرب',
#  'جهد',
#  'عرب',
#  'جهد',
#  'قندهار',
#  'جهد',
#  'عرب',
#  'وصل',
#  'اخه',
#  'نحز',
#  'كبل',
#  'الي',
#  'جهد',
#  'خوس',
#  'جهد',
#  'عرب',
#  'وصل',
#  'اخه',
#  'نحز',
#  'كبل',
#  'الي',
#  'جهد',
#  'تور',
#  'بور',
#  'جهد',
#  'عرب',
#  'وصل',
#  'اخه',
#  'نحز',
#  'كبل',
#  'الي',
#  'اسر',
#  'عرب',
#  'غنس',
#  'جوز',
#  'اسر',
#  'جمل',
#  'جهد',
#  'عرب',
#  'رجل',
#  'غنس',
#  'قرب',
#  'جهد',
#  'احس',
#  'وقع',
#  'شهد',
#  'نهم',
#  'قرب',
#  'بطل',
#  'اسر',
#  'نهم',
#  'قرب',
#  'اخا',
#  'خرج',
#  'حدد',
#  'فغن',
#  'وعد',
#  'بلد',
#  'وبق',
#  'غنس',
#  'نهم',
#  'مايسوء',
#  'امر',
#  'حلفاء',
#  'بلغ',
#  'عدد',
#  'عرب',
#  'عرك',
#  'خضو',
#  'امر',
#  'قلع',
#  'جنك',
#  'قندهار',
#  'تور',
#  'بور',
#  'شهي',
#  'كانت',
#  'قوه',
#  'عرب',
#  'حشد',
#  'امر',
#  'قوت',
#  'وقو',
#  'حلفاء',
#  'فان',
#  'عدد',
#  'كانت',
#  'تسق',
#  'قيد',
#  'بنتاجون',
#  'عمل',
#  'قحم',
#  'امر',
#  'ءمن',
#  'رور',
#  'عشر',
#  'ايم',
#  'قرب',
#  'شعب',
#  'نصف',
#  'ليل',
#  'نبه',
#  'قندهار',
#  'اصو',
#  'قتل',
#  'شدد',
#  'امر',
#  'ءمن',
#  'سمر',
#  'قتل',
#  'قرب',
#  'ساع',
#  'وشر',
#  'لال',
#  'طءر',
#  'c',
#  'والتي',
#  'شبك',
#  'جهد',
#  'شلك',
#  'جهز',
#  'وكانت',
#  'حدث',
#  'شبك',
#  'قندهار',
#  'دفع',
#  'جمع',
#  'طلب',
#  'بتج',
#  'وقع',
#  'فور',
#  'تحر',
#  'جمع',
#  'شهداء',
#  'قيد',
#  'بطل',
#  'حمز',
#  'زبر',
#  'رحم',
#  'الل',
#  'قرب',
#  'نطق',
#  'وكانت',
#  'جمع',
#  'وصل',
#  'نفر',
#  'زبر',
#  'حءل',
#  'فرد',
#  'تحر',
#  'ونس',
#  'صرخ',
#  'نجر',
#  'حال',
#  'قرب',
#  'وقع',
#  'خلل',
#  'ايم',
#  'سبق',
#  'كانت',
#  'طءر',
#  'امر',
#  'سبح',
#  'سمء',
#  'قندهار',
#  'نزل',
#  'ستي',
#  'قرب',
#  'حال',
#  'لاستفزاز',
#  'وحد',
#  'جهد',
#  'والتي',
#  'مرت',
#  'عصب',
#  'عدم',
#  'لرد',
#  'فزز',
#  'طءر',
#  'وذل',
#  'تفق',
#  'سلف',
#  'علق',
#  'باستخدام',
#  'سلح',
#  'تاح',
#  'هجم',
#  'هليكوبتر',
#  'قط',
#  'فعل',
#  'هدء',
#  'جهد',
#  'قوت',
#  'امر',
#  'غمر',
#  'حول',
#  'قيم',
#  'بغر',
#  'صمت',
#  'امر',
#  'ءمن',
#  'مثل',
#  'يلم',
#  'كثف',
#  'طلع',
#  'طقت',
#  'ولم',
#  'اكد',
#  'خلو',
#  'دفع',
#  'بسط',
#  'حرس',
#  'كان',
#  'سرق',
#  'اعد',
#  'هجم',
#  'ارو',
#  'نسب',
#  'عمد',
#  'فجا',
#  'رعه',
#  'طءر',
#  'وصل',
#  'قرب',
#  'ولي',
#  'ارض',
#  'فجا',
#  'بمج',
#  'بغت',
#  'طلق',
#  'شلك',
#  'مم',
#  'هال',
#  'عليها',
#  'رشش',
#  'جنب',
#  'اهل',
#  'اسد',
#  'طلب',
#  'صمت',
#  'هدء',
#  'وبغ',
#  'عدو',
#  'غرر',
#  'اسقط',
#  'طءر',
#  'ولي',
#  'اصب',
#  'طءر',
#  'ثني',
#  'انه',
#  'تمك',
#  'هروب',
#  'حول',
#  'فرد',
#  'حرس',
#  'فقد',
#  'طءر',
#  'حمل',
#  'هلك',
#  'عدو',
#  'دخل',
#  'يمل',
#  'جمع',
#  'بدر',
#  'طءر',
#  'بكف',
#  'واع',
#  'غربل',
#  'نطق',
#  'طلق',
#  'حرس',
#  'ستر',
#  'هجم',
#  'طءر',
#  'جيت',
#  'تغط',
#  'نطق',
#  'وطر',
#  'c',
#  'جهز',
#  'بشل',
#  'جوه',
#  'دعم',
#  'وحد',
#  'ضرب',
#  'حار',
#  'قدم',
#  'منع',
#  'جهد',
#  'سعف',
#  'وقف',
#  'رسل',
#  'طءر',
#  'هليكوبتر',
#  'نار',
#  'قريبه',
#  'عزل',
#  'منطقه',
#  'تيق',
#  'عدو',
#  'فرغ',
#  'سحه',
#  'حرس',
#  'فور',
#  'سرع',
#  'امر',
#  'ارسال',
#  'هليكوبتر',
#  'رفع',
#  'طءر',
#  'حطم',
#  'طقم',
#  'هلك',
#  'دار',
#  'سعه',
#  'نصف',
#  'قتل',
#  'شرس',
#  'تمك',
#  'وحد',
#  'امر',
#  'نطق',
#  'رفع',
#  'جثث',
#  'طءر',
#  'تحر',
#  'انه',
#  'سقط',
#  'نهم',
#  'خري',
#  'صجراء',
#  'امر',
#  'ءمن',
#  'وجد',
#  'بكر',
#  'ونش',
#  'مقطوع',
#  'ولك',
#  'رسل',
#  'ونش',
#  'طءر',
#  'رفع',
#  'حطم',
#  'شءم',
#  'خرج',
#  'حال',
#  'ستر',
#  'عمل',
#  'لقو',
#  'كماندوز',
#  'قندهار',
#  'صبح',
#  'كانت',
#  'كشف',
#  'نره',
#  'زود',
#  'جند',
#  'امر',
#  'والتي',
#  'يستخدمون',
#  'ضيع',
#  'اطلاق',
#  'اشر',
#  'يضء',
#  'اخري',
#  'زرقاء',
#  'ايد',
#  'حرس',
#  'امر',
#  'ءمن',
#  'اثر',
#  'طءر',
#  'حطم',
#  'طرز',
#  'شينو',
#  'عجل',
#  'الواح',
#  'والكتروني',
#  'ناثر',
#  'عرك',
#  'رفع',
#  'عني',
#  'طلب',
#  'درج',
#  'كبر',
#  'جدا',
#  'بهذا',
#  'وفق',
#  'مكن',
#  'الل',
#  'عرك',
#  'سقط',
#  'طءر',
#  'طرز',
#  'شينو',
#  'والتي',
#  'طقم',
#  'حمل',
#  'فرد',
#  'وحد',
#  'كمندوز',
#  'نشر',
#  'خبر',
#  'قندهار',
#  'فرح',
#  'سلم',
#  'كثيرا',
#  'ستر',
#  'امر',
#  'امر',
#  'وغط',
#  'عرض',
#  'يلم',
#  'صور',
#  'عمل',
#  'فشل',
#  'طار',
#  'سفر',
#  'والتي',
#  'نري',
#  'قصه',
#  'علي',
#  'ملا',
#  'قءد',
#  'جمع',
#  'طلب',
#  'منطقه',
#  'تبع',
#  'صدر',
#  'نفس']

# %%
for index, score in sorted(lda_model[bow_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.4781235456466675
# Topic: 0.017*"علم" + 0.010*"شكل" + 0.007*"كثر" + 0.007*"فكر" + 0.007*"وضع" + 0.006*"كلم" + 0.006*"عرف" + 0.005*"جمع" + 0.005*"دكتور" + 0.005*"كتب"
#
# Score: 0.3324850797653198
# Topic: 0.014*"سلم" + 0.011*"علم" + 0.010*"قلب" + 0.006*"ذكر" + 0.006*"عمل" + 0.006*"جمع" + 0.006*"امر" + 0.005*"عبد" + 0.005*"انس" + 0.004*"رحم"
#
# Score: 0.18659639358520508
# Topic: 0.008*"علم" + 0.008*"زوج" + 0.007*"عرف" + 0.007*"سلم" + 0.007*"كلم" + 0.006*"عمل" + 0.006*"امر" + 0.006*"جمع" + 0.006*"دخل" + 0.005*"ولد"

# %% [markdown]
# Our test document has the highest probability to be part of the topic that our model assigned, which is the accurate classification.

# %% [markdown]
# Performance evaluation by classifying sample document using LDA TF-IDF model.

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.9058488011360168
# Topic: 0.003*"زوج" + 0.003*"شكل" + 0.003*"علم" + 0.002*"سلم" + 0.002*"عمل" + 0.002*"كلم" + 0.002*"شعر" + 0.002*"رحم" + 0.002*"كثر" + 0.002*"عرف"
#
# Score: 0.09245883673429489
# Topic: 0.004*"زوج" + 0.003*"علج" + 0.003*"رحم" + 0.003*"شكل" + 0.002*"سلم" + 0.002*"جمع" + 0.002*"دكتور" + 0.002*"شكر" + 0.002*"عمل" + 0.002*"شعر"

# %% [markdown]
# Our test document has the highest probability to be part of the topic that our model assigned, which is the accurate classification.

# %% [markdown]
# Testing model on unseen document

# %%
unseen_document = 'أنا أعاني من الإكتئاب بسبب أنني أتعرض للإهانة لماذا أنا يا رب  '
bow_vector = dictionary.doc2bow(clean(unseen_document))
for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.8874394297599792	 Topic: 0.013*"شكل" + 0.013*"علج" + 0.011*"رحم" + 0.009*"عمل" + 0.009*"جمع"
# Score: 0.012509438209235668	 Topic: 0.010*"شعر" + 0.008*"عمل" + 0.007*"فكر" + 0.006*"كثر" + 0.006*"علم"
# Score: 0.01250746101140976	 Topic: 0.008*"علم" + 0.008*"زوج" + 0.007*"عرف" + 0.007*"سلم" + 0.007*"كلم"
# Score: 0.012507245875895023	 Topic: 0.013*"شكل" + 0.012*"طفل" + 0.012*"علم" + 0.009*"جمع" + 0.008*"عرف"
# Score: 0.012506572529673576	 Topic: 0.021*"رحم" + 0.014*"علي" + 0.011*"سلم" + 0.007*"علم" + 0.007*"صدق"
# Score: 0.012506390921771526	 Topic: 0.010*"شعر" + 0.008*"نظر" + 0.007*"قلب" + 0.005*"حول" + 0.005*"علم"
# Score: 0.012506315484642982	 Topic: 0.017*"علم" + 0.010*"شكل" + 0.007*"كثر" + 0.007*"فكر" + 0.007*"وضع"
# Score: 0.012506249360740185	 Topic: 0.012*"سلم" + 0.012*"رحم" + 0.011*"جمع" + 0.009*"راه" + 0.008*"كتب"
# Score: 0.012505576945841312	 Topic: 0.014*"سلم" + 0.011*"علم" + 0.010*"قلب" + 0.006*"ذكر" + 0.006*"عمل"
# Score: 0.012505319900810719	 Topic: 0.019*"سلم" + 0.018*"زوج" + 0.014*"رسل" + 0.007*"كلم" + 0.006*"رحم"
